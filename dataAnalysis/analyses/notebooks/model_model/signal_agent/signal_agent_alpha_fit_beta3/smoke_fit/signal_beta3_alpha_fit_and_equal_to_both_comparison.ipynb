# %% [markdown]
# # SignalAgent Beta=3 Alpha Fit and Equal-to-Both Comparison
#
# Fitted setting: beta = 3.0, lambda = 0.125, alpha = 0.

# %%
from pathlib import Path
import pandas as pd
OUT = Path(r'dataAnalysis/analyses/outputs/model_model/signal_agent/signal_agent_alpha_fit_beta3/smoke_fit')
fit_df = pd.read_csv(OUT / 'signal_alpha_fit_beta3_average_equal.csv')
four_df = pd.read_csv(OUT / 'signal_alpha_beta3_average_equal_4measures.csv')
equal_df = pd.read_csv(OUT / 'equal_to_both_signal_joint_rl_human_4panel_summary.csv')
all_df = pd.read_csv(OUT / 'all_distance_signal_joint_rl_human_4panel_summary.csv')

# %% [markdown]
# ## Alpha Fit

# %%
fit_df.round(4)

# %% [markdown]
# ## Four Measures Across Alpha

# %%
four_df.round(3)

# %% [markdown]
# ## Equal-to-Both Comparison

# %%
equal_df.round(3)

# %% [markdown]
# ## All Distance Conditions Comparison

# %%
all_df.round(3)
