# %% [markdown]
# # Shared-Agency Log-Odds Eta Sweep

# %%
from pathlib import Path
import pandas as pd
OUT = Path(r'/Users/chengshaozhe/Documents/DukeECClab/code/multiplePlayerGridGame_socketIO/dataAnalysis/model_model/shared_agency_log_odds_eta_sweep')
sweep = pd.read_csv(OUT / 'shared_agency_log_odds_eta_sweep.csv')
best = pd.read_csv(OUT / 'shared_agency_log_odds_best_eta.csv')
summary = pd.read_csv(OUT / 'shared_agency_log_odds_summary.csv')
raw_sources = pd.read_csv(OUT / 'shared_agency_log_odds_raw_sources.csv')

# %% [markdown]
# ## Best eta

# %%
best.round(3)

# %% [markdown]
# ## Sweep

# %%
sweep.round(3)

# %% [markdown]
# ## Posterior predictive summary

# %%
summary.round(3)

# %% [markdown]
# ## Raw sources

# %%
raw_sources
