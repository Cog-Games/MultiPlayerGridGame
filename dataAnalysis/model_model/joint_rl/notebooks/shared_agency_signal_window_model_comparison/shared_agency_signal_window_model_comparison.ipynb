# %% [markdown]
# # Shared-Agency Signal-Window Model Comparison

# %%
from pathlib import Path
import pandas as pd
OUT = Path(r'/Users/chengshaozhe/Documents/DukeECClab/code/multiplePlayerGridGame_socketIO/dataAnalysis/model_model/shared_agency_signal_window_model_comparison')
model_nll = pd.read_csv(OUT / 'signal_window_model_comparison_nll.csv')
cv = pd.read_csv(OUT / 'signal_window_model_comparison_cv_folds.csv')
grid = pd.read_csv(OUT / 'signal_window_lambda_alpha_grid.csv')
behavior = pd.read_csv(OUT / 'shared_agency_step_level_behavior_summary.csv')
trial_vs_signal_window = pd.read_csv(OUT / 'trial_level_vs_signal_window_best_shared_agency.csv')

# %% [markdown]
# ## Held-Out Signal-Window NLL

# %%
model_nll.round(3)

# %% [markdown]
# ## Lambda x Alpha Grid

# %%
grid.sort_values('negative_log_likelihood').head(10).round(3)

# %% [markdown]
# ## Trial-Level Best vs Signal-Window Best

# %%
trial_vs_signal_window.round(3)
