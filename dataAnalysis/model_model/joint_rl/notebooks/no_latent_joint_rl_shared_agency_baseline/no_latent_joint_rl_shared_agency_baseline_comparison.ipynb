# %% [markdown]
# # Shared-Agency Communicative Action Mixture (Legibility Over Alternatives) Baseline Comparison
#
# Compares Individual RL, Joint RL, shared agency no commitment/no signaling, shared agency commitment/no signaling, full shared agency with Communicative Action Mixture (Legibility Over Alternatives), and Human-Human.

# %%
from pathlib import Path
import pandas as pd
OUT = Path(r'/Users/chengshaozhe/Documents/DukeECClab/code/multiplePlayerGridGame_socketIO/dataAnalysis/model_model/joint_rl/outputs/no_latent_joint_rl_shared_agency_baseline')
summary = pd.read_csv(OUT / 'no_latent_joint_rl_shared_agency_summary.csv')
metrics = pd.read_csv(OUT / 'no_latent_joint_rl_shared_agency_metric_long.csv')
raw_sources = pd.read_csv(OUT / 'no_latent_joint_rl_shared_agency_raw_sources.csv')
lambda_sweep = pd.read_csv(OUT / 'shared_agency_commitment_no_signaling_lambda_sweep.csv')
lambda_sweep_best = pd.read_csv(OUT / 'shared_agency_commitment_no_signaling_best_lambda.csv')
alpha_sweep = pd.read_csv(OUT / 'shared_agency_commitment_signaling_alpha_sweep.csv')
alpha_sweep_best = pd.read_csv(OUT / 'shared_agency_commitment_signaling_best_alpha.csv')
joint_sweep = pd.read_csv(OUT / 'shared_agency_commitment_signaling_joint_lambda_alpha_sweep.csv')
joint_sweep_best = pd.read_csv(OUT / 'shared_agency_commitment_signaling_best_joint_lambda_alpha.csv')
costly_dir = OUT.parents[2] / 'shared_agency_costly_mixture_rho_sweep'
costly_sweep = pd.read_csv(costly_dir / 'shared_agency_costly_mixture_rho_sweep.csv')
costly_best = pd.read_csv(costly_dir / 'shared_agency_costly_mixture_best_rho.csv')
btom_summary = pd.read_csv(OUT / 'no_latent_joint_rl_shared_agency_btom_summary.csv')
btom_step1 = pd.read_csv(OUT / 'no_latent_joint_rl_shared_agency_btom_step1_summary.csv')

# %% [markdown]
# ## Raw Sources

# %%
raw_sources

# %% [markdown]
# ## Summary Metrics

# %%
summary.round(2)

# %% [markdown]
# ## Long Metric Table

# %%
metrics.round(2)

# %% [markdown]
# ## Commitment-Only Lambda Sweep

# %%
lambda_sweep.round(3)

# %% [markdown]
# ## Best Commitment-Only Lambda

# %%
lambda_sweep_best.round(3)

# %% [markdown]
# ## Full Shared-Agency Communicative Action Mixture (Legibility Over Alternatives) Rho Sweep

# %%
costly_sweep.round(3)

# %% [markdown]
# ## Best Communicative Action Mixture (Legibility Over Alternatives) Setting

# %%
costly_best.round(3)

# %% [markdown]
# ## Legacy RSA Alpha Sweep

# %%
alpha_sweep.round(3)

# %% [markdown]
# ## Best Legacy RSA Alpha

# %%
alpha_sweep_best.round(3)

# %% [markdown]
# ## Legacy RSA Joint Lambda x Alpha Search

# %%
joint_sweep.sort_values('binomial_nll').head(10).round(3)

# %% [markdown]
# ## Best Legacy RSA Joint Lambda x Alpha Pair

# %%
joint_sweep_best.round(3)

# %% [markdown]
# ## BToM First 5-Step Summary

# %%
btom_summary.round(4)

# %% [markdown]
# ## BToM Step 1 Summary

# %%
btom_step1.round(4)
