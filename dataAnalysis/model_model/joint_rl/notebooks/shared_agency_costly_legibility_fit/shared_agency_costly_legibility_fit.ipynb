# %% [markdown]
# # Shared-Agency Costly Legibility Utility Fit

# %%
from pathlib import Path
import pandas as pd
OUT = Path(r'/Users/chengshaozhe/Documents/DukeECClab/code/multiplePlayerGridGame_socketIO/dataAnalysis/model_model/shared_agency_costly_legibility_fit')
step0 = pd.read_csv(OUT / 'step0_model_summary.csv')
step1 = pd.read_csv(OUT / 'step1_model_summary.csv')
step13 = pd.read_csv(OUT / 'step1_3_model_summary.csv')
step0_grid = pd.read_csv(OUT / 'step0_eta_sweep.csv')
step1_grid = pd.read_csv(OUT / 'step1_eta_sweep.csv')
step13_grid = pd.read_csv(OUT / 'step1_3_eta_sweep.csv')

# %% [markdown]
# ## New-goal Presentation Step

# %%
step0.round(3)

# %% [markdown]
# ## Step 1

# %%
step1.round(3)

# %% [markdown]
# ## Steps 1-3

# %%
step13.round(3)

# %% [markdown]
# ## Eta Sweeps

# %%
step0_grid.round(3), step1_grid.round(3), step13_grid.round(3)
