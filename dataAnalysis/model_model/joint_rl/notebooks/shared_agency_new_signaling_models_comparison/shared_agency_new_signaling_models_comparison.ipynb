# %% [markdown]
# # Shared-Agency New Signaling Models Comparison

# %%
from pathlib import Path
import pandas as pd
OUT = Path(r'/Users/chengshaozhe/Documents/DukeECClab/code/multiplePlayerGridGame_socketIO/dataAnalysis/model_model/shared_agency_new_signaling_models_comparison')
summary = pd.read_csv(OUT / 'new_signaling_models_summary.csv')
best = pd.read_csv(OUT / 'new_signaling_models_best_parameters.csv')
sweep = pd.read_csv(OUT / 'new_signaling_models_sweep.csv')
raw_sources = pd.read_csv(OUT / 'new_signaling_models_raw_sources.csv')

# %% [markdown]
# ## Summary metrics

# %%
summary.round(2)

# %% [markdown]
# ## Best parameters

# %%
best.round(3)

# %% [markdown]
# ## Sweep

# %%
sweep.round(3)

# %% [markdown]
# ## Raw sources

# %%
raw_sources
