# %% [markdown]
# # Shared-Agency Step-Level Model Comparison

# %%
from pathlib import Path
import pandas as pd
OUT = Path(r'/Users/chengshaozhe/Documents/DukeECClab/code/multiplePlayerGridGame_socketIO/dataAnalysis/model_model/shared_agency_step_level_model_comparison')
model_nll = pd.read_csv(OUT / 'step_level_model_comparison_nll.csv')
cv = pd.read_csv(OUT / 'step_level_model_comparison_cv_folds.csv')
costly_grid = pd.read_csv(OUT / 'shared_agency_step_level_costly_mixture_rho_grid.csv')
legacy_rsa_grid = pd.read_csv(OUT / 'legacy_rsa_step_level_lambda_alpha_grid.csv')
behavior = pd.read_csv(OUT / 'shared_agency_step_level_behavior_summary.csv')
trial_vs_step = pd.read_csv(OUT / 'trial_level_vs_step_level_best_shared_agency.csv')

# %% [markdown]
# ## Held-Out Step-Level Model Comparison

# %%
model_nll.round(3)

# %% [markdown]
# ## Full Shared-Agency Communicative Action Mixture (Legibility Over Alternatives) Rho Grid

# %%
costly_grid.sort_values('negative_log_likelihood').head(10).round(3)

# %% [markdown]
# ## Legacy RSA Lambda x Alpha Diagnostic Grid

# %%
legacy_rsa_grid.sort_values('negative_log_likelihood').head(10).round(3)

# %% [markdown]
# ## Behavioral Posterior Predictive Checks

# %%
behavior.round(2)

# %% [markdown]
# ## Trial-Level Best vs Step-Level Best

# %%
trial_vs_step.round(3)
