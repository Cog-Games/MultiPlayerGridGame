# %% [markdown]
# # Shared-Agency Step-1 Model Comparison

# %%
from pathlib import Path
import pandas as pd
OUT = Path(r'/Users/chengshaozhe/Documents/DukeECClab/code/multiplePlayerGridGame_socketIO/dataAnalysis/model_model/shared_agency_step1_model_comparison')
model_nll = pd.read_csv(OUT / 'step1_model_comparison_nll.csv')
grid = pd.read_csv(OUT / 'step1_lambda_alpha_grid.csv')
trial_vs_step1 = pd.read_csv(OUT / 'trial_level_vs_step1_best_shared_agency.csv')
behavior = pd.read_csv(OUT / 'shared_agency_step_level_behavior_summary.csv')

# %% [markdown]
# ## Held-Out Step-1 NLL

# %%
model_nll.round(3)

# %% [markdown]
# ## Lambda x Alpha Grid

# %%
grid.sort_values('negative_log_likelihood').head(10).round(3)

# %% [markdown]
# ## Trial-Level Best vs Step-1 Best

# %%
trial_vs_step1.round(3)

# %% [markdown]
# ## Behavioral Posterior Predictive Checks

# %%
behavior.round(2)
