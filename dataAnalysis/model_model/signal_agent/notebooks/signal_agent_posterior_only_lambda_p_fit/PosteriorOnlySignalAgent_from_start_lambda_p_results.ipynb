# %% [markdown]
# # samplePosteriorOnlyGoalAndSignal_fromStart standardized model-model results
#
# This notebook mirrors the current `model_model_comparison.html` plotting logic.
#
# - Fit/sweep plot: average and equal-to-both model metrics with the best fit highlighted.
# - Result plot: model vs Human-Human side-by-side, shown for average all 2P3G and equal-to-both, with 95% CI error bars.
# - Commitment uses `finalReachedGoal == firstDetectedSharedGoal`.

# %% [markdown]
# ## Sweep / Fit Plot
#
# ![sweep](../../../report_assets/samplePosteriorOnlyGoalAndSignal_fromStart_standard_sweep_best.png)

# %% [markdown]
# ## Model vs Human-Human
#
# ![bar](../../../report_assets/samplePosteriorOnlyGoalAndSignal_fromStart_standard_human_side_by_side_bar_4panel.png)

# %%
import pandas as pd
summary = pd.read_csv(r'../../../report_assets/samplePosteriorOnlyGoalAndSignal_fromStart_standard_human_side_by_side_summary.csv')
summary.round(3)
